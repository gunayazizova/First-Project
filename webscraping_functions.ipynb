# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_Human_Development_Index_score'
url2 = 'https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_Human_Development_Index_score'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.find_all("table")[0]
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>State,<br/>federal district,<br/> or territory
# </th>
# <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th></tr>
# <tr>
# <td rowspan="2">1
# </td>
# ...

# %%
soup.find_all("table")[0].select("tbody")
# Out:
# [<tbody><tr>
#  <th>Rank
#  </th>
#  <th>State,<br/>federal district,<br/> or territory
#  </th>
#  <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
#  </th></tr>
#  <tr>
#  <td rowspan="2">1
#  </td>
# ...

# %%
soup.find_all("table")[0].select("tbody")[0]
# Out:
# <tbody><tr>
# <th>Rank
# </th>
# <th>State,<br/>federal district,<br/> or territory
# </th>
# <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th></tr>
# <tr>
# <td rowspan="2">1
# </td>
# ...

# %%
soup.find_all("tr")
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>State,<br/>federal district,<br/> or territory
#  </th>
#  <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
#  </th></tr>,
#  <tr>
#  <td rowspan="2">1
#  </td>
# ...

# %%
soup.find_all("tr")[0]
# Out:
# <tr>
# <th>Rank
# </th>
# <th>State,<br/>federal district,<br/> or territory
# </th>
# <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th></tr>

# %%
soup.find_all("tr")[0].find("th").get_text().strip()
# Out:
# 'Rank'

# %%
soup.find_all("tr")[0].find_all("th")[2].get_text().strip()
# Out:
# 'HDI (2022)[note 1][1]'

# %%
soup.find_all("tr")
# Out:
# [<tr>
#  <th>Rank
#  </th>
#  <th>State,<br/>federal district,<br/> or territory
#  </th>
#  <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
#  </th></tr>,
#  <tr>
#  <td rowspan="2">1
#  </td>
# ...

# %%
soup.find_all("tr")[0].find_all("td")
# Out:
# []

# %%
soup.find_all("tr")[1].find_all("td")
# Out:
# [<td rowspan="2">1
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
#  </td>,
#  <td rowspan="2">0.956
#  </td>]

# %%
soup.find_all("tr")[1].find_all("td")
# Out:
# [<td rowspan="2">1
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
#  </td>,
#  <td rowspan="2">0.956
#  </td>]

# %%
soup.find_all("tr")[1].find_all("td")[0]
# Out:
# <td rowspan="2">1
# </td>

# %%
soup.find_all("tr")[1].find_all("td")[0].get_text().strip()
# Out:
# '1'

# %%
for i in soup.find_all("tr"):
    if i == 0:
        continue
    for j in i.find_all("td rowspan"):
        #print(j)
        if 'rowspan' in str(j):
            temp_var = j.get_text().strip()
            
            print("potato")
        temp_var = j.get_text().strip()
        print(temp_var)

# %%
for i in soup.find_all("tr"):
    if i == 0:
        continue
    for j in i.find_all("td"):
        print(j)
        print("-----------------")
# Out:
# <td rowspan="2">1
# </td>
# -----------------
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
# </td>
# -----------------
# <td rowspan="2">0.956
# </td>
# -----------------
# ...

# %%
def nice_function():
    headers_list = []
    rank_list = []
    state_list = []
    hdi_list = []

    #### for the header

    for h in soup.find_all("tr")[0].find_all("th"):
        print(h)
        temp_head = h.get_text().strip()
        headers_list.append(temp_head)


    ####
        
    
    #soup.find_all("tr")[0].find("th").get_text().strip()

    for i in soup.find_all("tr"):
        if i == 0:
            continue
        
        for j in i.find_all("td"):
            if j == 0:
                rank_list.append(


    ## start from range 1
    #for i in soup.find_all("tr"):

    

    return headers_list

# %%
soup.find_all("tr")[1].find_all("td")
# Out:
# [<td rowspan="2">1
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
#  </td>,
#  <td rowspan="2">0.956
#  </td>]

# %%
soup.find_all("tr")[4].find_all("td", attrs={"rowspan": 3})

# %%
soup.find_all("tr")[4].find_all("td", attrs={"rowspan": 2})
# Out:
# []

# %%
empty_list = []

# %%
new_list = soup.find_all("tr")[4].find_all("td", attrs={"rowspan": 2})

# %%
new_list
# Out:
# []

# %%
if empty_list:
    print("Potato")
# Out:
# Potato

# %%
headers_list = []
rank_list = []
state_list = []
hdi_list = []

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
rank_list
# Out:
# []

# %%
isinstance( 'x', basestring )

# %%
    if len(i) == 6:
        for g in i.find_all("td"):
            temp_var = j.get_text().strip()
            try:
                temp_var = float(temp_var)
            except:
                for index in range(3):
                    state_list.append(temp_var)
                #state_list.append((i+1).get_text().strip())
                #state_list.append((i+2).get_text().strip())
            else:
                #print(type(temp_var))
                if isinstance(temp_var, float):
                #if type(temp_var) == "float":
                    for index in range(3):
                        #print(temp_var)
                        if temp_var < 1:
                            hdi_list.append(temp_var)
                        else:
                            rank_list.append(temp_var)

# %%
headers_list = []
rank_list = []
state_list = []
hdi_list = []

# %%
my_string = "~0.901 (2017)"

# %%
my_string
# Out:
# '~0.901 (2017)'

# %%
if "." in my_string:
    my_string = my_string.split(" ")[0]
    if "~" in my_string:
        my_string = my_string[1:]

# %%
my_string
# Out:
# '0.901'

# %%
var1[0]
# Out:
# '0.955'

# %%
for n in range(-1):
    print("Potato")

# %%
        for n in diff:
            rank_list.append(last_rank)
            hdi_list.append(last_hdi)

# %%
my_string = "United States (average)"

# %%
if 3 != 2 != 1:
    print("potato")
# Out:
# potato

# %%
headers_list = []
rank_list = []
state_list = []
hdi_list = []

# %%
if (len(rank_list) != len(state_list) != len(hdi_list)) and (rank_list and state_list and hdi_list):

# %%
if (3 != 2 != 1) and (3 and 2 and 1):
    print("potato")
# Out:
# potato

# %%
headers_list = []
rank_list = []
state_list = []
hdi_list = []

# %%
##### WE ARE HERE


last_rank = 0
last_hdi = 0.0
last_state = ""

for i in soup.find_all("tr"):

    


    if i == 0:
        continue

    for j in i.find_all("td"):


        ### J BECOMES DEFINED
        
        temp_var = j.get_text().strip()

        ### J BECOMES DEFINED
        



        

        if "." in temp_var:
            temp_var = temp_var.split(" ")[0]
            if "~" in temp_var:
                temp_var = temp_var[1:]
        
        try:
            temp_var = float(temp_var)
        except:

            
            if len(j) >= 3:
                state_list.append(temp_var)

            else:
                if "—" in temp_var:
                    rank_list.append(0)
                else:
                    
                    if temp_var[-1] == "]":
                        temp_var = temp_var.split(" [")[0]
                        state_list.append(temp_var)
                        last_state = temp_var
                    else:
                        state_list.append(temp_var)
                        last_state = temp_var
                        #print(last_state)
                        #print(temp_var)
        else:
            if temp_var < 0.999999 :
                hdi_list.append(temp_var)
                last_hdi = temp_var
            else:
                rank_list.append(temp_var)
                last_rank = temp_var     

        temp_var = str(temp_var)
        if (temp_var.isalpha() or temp_var == "United States (average)"):
            #diff = (len(state_list)) - (len(rank_list))
            #diff2 = (len(state_list)) - (len(hdi_list))
            
            if len(state_list) > len(rank_list):
                #for n in range(diff):
                rank_list.append(last_rank)
                
            if len(state_list) > len(hdi_list):
                hdi_list.append(last_hdi)

            
            #for n in range(diff2):
                #rank_list.append(last_rank)
                #hdi_list.append(last_hdi)

# %%
for index in range(1):
    print(len(rank_list))
    print(len(state_list))
    print(len(hdi_list))
# Out:
# 57
# 76
# 58

# %%
rank_list
# Out:
# [1.0,
#  0.0,
#  3.0,
#  0.956,
#  0.952,
#  5.0,
#  0.952,
#  6.0,
#  0.951,
#  0,
#  7.0,
#  0.947,
#  8.0,
#  0.947,
#  9.0,
#  10.0,
#  0.943,
#  11.0,
#  0.942,
#  12.0,
#  0.939,
#  13.0,
#  14.0,
#  0.937,
#  15.0,
#  0.936,
#  16.0,
#  18.0,
#  0.934,
#  19.0,
#  0.932,
#  0.931,
#  0.931,
#  22.0,
#  0.931,
#  0.929,
#  25.0,
#  0.929,
#  0,
#  0.928,
#  26.0,
#  0.927,
#  27.0,
#  0.925,
#  28.0,
#  0.924,
#  29.0,
#  0.923,
#  30.0,
#  0.922,
#  31.0,
#  0.921,
#  32.0,
#  0.916,
#  33.0,
#  0.913,
#  34.0,
#  0.908,
#  36.0,
#  0.908,
#  37.0,
#  0.907,
#  38.0,
#  0.906,
#  39.0,
#  0.905,
#  40.0,
#  0.904,
#  0,
#  0.903,
#  41.0,
#  42.0,
#  0.894,
#  43.0,
#  0.893,
#  0,
#  44.0,
#  45.0,
#  0.884,
#  46.0,
#  0.881,
#  47.0,
#  0.88,
#  0,
#  48.0,
#  0.879,
#  0,
#  49.0,
#  50.0,
#  0.87,
#  0]

# %%
hdi_list
# Out:
# [0.956,
#  0.956,
#  0.952,
#  0.952,
#  0.951,
#  0.95,
#  0.947,
#  0.947,
#  0.945,
#  0.943,
#  0.942,
#  0.939,
#  0.938,
#  0.937,
#  0.936,
#  0.935,
#  0.934,
#  0.934,
#  0.932,
#  0.931,
#  0.931,
#  0.931,
#  0.929,
#  0.929,
#  0.929,
#  0.928,
#  0.927,
#  0.925,
#  0.924,
#  0.923,
#  0.922,
#  0.921,
#  0.916,
#  0.913,
#  0.91,
#  0.908,
#  0.908,
#  0.907,
#  0.906,
#  0.905,
#  0.904,
#  0.903,
#  0.901,
#  0.894,
#  0.893,
#  0.892,
#  0.892,
#  0.884,
#  0.881,
#  0.88,
#  0.879,
#  0.879,
#  0.877,
#  0.875,
#  0.87,
#  0.858,
#  0.827]

# %%
len(rank_list)
# Out:
# 42

# %%
len(hdi_list)
# Out:
# 48

# %%
len(state_list)
# Out:
# 76

# %%
##### OLD



for i in soup.find_all("tr"):
    #print(i)
    if i == 0:
        continue


    #print(i.find_all("td"))
    #if i.find_all("td"):
        #print(i.find_all("td")[0])
        #print("----------")

    for j in i.find_all("td"):
        temp_var = j.get_text().strip()

        
        if i.find_all("td", attrs={"rowspan": 3}):
            try:
                temp_var = float(temp_var)
            except:
                for index in range(3):
                    state_list.append(temp_var)
                #state_list.append((i+1).get_text().strip())
                #state_list.append((i+2).get_text().strip())
            else:
                #print(type(temp_var))
                if isinstance(temp_var, float):
                #if type(temp_var) == "float":
                    for index in range(3):
                        #print(temp_var)
                        if temp_var < 1:
                            hdi_list.append(temp_var)
                        else:
                            rank_list.append(temp_var)


        if i.find_all("td", attrs={"rowspan": 2}):
            try:
                temp_var = float(temp_var)
            except:
                for index in range(2):
                    state_list.append(temp_var)
                #state_list.append((i+1).get_text().strip())
                #state_list.append((i+2).get_text().strip())
            else:
                #print(type(temp_var))
                if isinstance(temp_var, float):
                #if type(temp_var) == "float":
                    for index in range(2):
                        #print(temp_var)
                        if temp_var < 1:
                            hdi_list.append(temp_var)
                        else:
                            rank_list.append(temp_var)


        if i.find_all("td", attrs={"rowspan": 1}):
            try:
                temp_var = float(temp_var)
            except:
                for index in range(1):
                    state_list.append(temp_var)
                #state_list.append((i+1).get_text().strip())
                #state_list.append((i+2).get_text().strip())
            else:
                print(type(temp_var))
                if isinstance(temp_var, float):
                #if type(temp_var) == "float":
                    for index in range(2):
                        #print(temp_var)
                        if temp_var < 1:
                            hdi_list.append(temp_var)
                        else:
                            rank_list.append(temp_var)

        print("---------")
        print(f"Lenght is {(len(j))}")
        print(j)
        print("---------")
    
            

                    
                
            #print(type(temp_var))
            #if type(temp_var) 
            #if (temp_var.isdigit()) == False:
                #state_list.append(temp_var)
            #for index in range(3):
                #rank_list.append(temp_var)
                #hdi_list.append(temp_var)
                #state_list.append(temp_var)
        #elif i.find_all("td", attrs={"rowspan": 2}):
            #if (temp_var.isdigit()) == False:
                #state_list.append(temp_var)
            #for index in range(2):
                #rank_list.append(temp_var)
                #hdi_list.append(temp_var)
                #state_list.append(temp_var)
        #else:
        #rank_list.append(temp_var)
        #hdi_list.append(temp_var)
        #state_list.append(temp_var)
# Out:
# ---------
# Lenght is 1
# <td rowspan="2">1
# </td>
# ---------
# ---------
# Lenght is 3
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
# </td>
# ---------
# ---------
# Lenght is 1
# <td rowspan="2">0.956
# </td>
# ---------
# ---------
# Lenght is 3
# ...

# %%
hdi_list
# Out:
# [0.956,
#  0.956,
#  0.952,
#  0.952,
#  0.947,
#  0.947,
#  0.934,
#  0.934,
#  0.931,
#  0.931,
#  0.931,
#  0.929,
#  0.929,
#  0.929,
#  0.908,
#  0.908]

# %%
rank_list
# Out:
# [1.0,
#  1.0,
#  3.0,
#  3.0,
#  16.0,
#  16.0,
#  19.0,
#  19.0,
#  19.0,
#  22.0,
#  22.0,
#  22.0,
#  34.0,
#  34.0]

# %%
state_list
# Out:
# ['Massachusetts',
#  'Massachusetts',
#  'Colorado',
#  'Colorado',
#  '—',
#  '—',
#  'District of Columbia',
#  'District of Columbia',
#  'North Dakota',
#  'North Dakota',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  'Maine',
#  'Maine',
#  'Maine',
#  'North Carolina',
#  'North Carolina']

# %%
for i in soup.find_all("tr"):
    if i == 0:
        continue

    for j in i.find_all("td"):
        temp_var = j.get_text().strip()
        #if i.find_all("td", attrs={"rowspan": 3}):
            #if (temp_var.isdigit()) == False:
                #state_list.append(temp_var)
            #for index in range(3):
                #rank_list.append(temp_var)
                #hdi_list.append(temp_var)
                #state_list.append(temp_var)
        #elif i.find_all("td", attrs={"rowspan": 2}):
            #if (temp_var.isdigit()) == False:
                #state_list.append(temp_var)
            #for index in range(2):
                #rank_list.append(temp_var)
                #hdi_list.append(temp_var)
                #state_list.append(temp_var)
        #else:
        rank_list.append(temp_var)
        hdi_list.append(temp_var)
        state_list.append(temp_var)

# %%
rank_list
# Out:
# ['19',
#  '19',
#  '19',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  '0.931',
#  '0.931',
#  '0.931',
#  '22',
#  '22',
#  '22',
#  'Maine',
#  'Maine',
#  'Maine',
#  '0.929',
#  '0.929',
#  '0.929',
#  '19',
#  '19',
#  '19',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  '0.931',
#  '0.931',
#  '0.931',
#  '22',
#  '22',
#  '22',
#  'Maine',
#  'Maine',
#  'Maine',
#  '0.929',
#  '0.929',
#  '0.929',
#  '1',
#  '1',
#  'Massachusetts',
#  'Massachusetts',
#  '0.956',
#  '0.956',
#  'New Hampshire',
#  '3',
#  '3',
#  'Colorado',
#  'Colorado',
#  '0.952',
#  '0.952',
#  'Washington',
#  '5',
#  'Minnesota',
#  '0.951',
#  '6',
#  'Connecticut',
#  '0.950',
#  '—',
#  '—',
#  'District of Columbia',
#  'District of Columbia',
#  '0.947',
#  '0.947',
#  '7',
#  'Hawaii',
#  '8',
#  'Vermont',
#  '0.945',
#  '9',
#  'New Jersey',
#  '0.943',
#  '10',
#  'Maryland',
#  '0.942',
#  '11',
#  'Virginia',
#  '0.939',
#  '12',
#  'Oregon',
#  '0.938',
#  '13',
#  'New York',
#  '0.937',
#  '14',
# ...

# %%
state_list
# Out:
# ['Alaska',
#  '0.931',
#  'Maine',
#  '0.929',
#  '19',
#  '19',
#  '19',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  '0.931',
#  '0.931',
#  '0.931',
#  '22',
#  '22',
#  '22',
#  'Maine',
#  'Maine',
#  'Maine',
#  '0.929',
#  '0.929',
#  '0.929']

# %%
hdi_list
# Out:
# ['19',
#  '19',
#  '19',
#  'Alaska',
#  'Alaska',
#  'Alaska',
#  '0.931',
#  '0.931',
#  '0.931',
#  '22',
#  '22',
#  '22',
#  'Maine',
#  'Maine',
#  'Maine',
#  '0.929',
#  '0.929',
#  '0.929']

# %%
for i in soup.find_all("tr"):

    if i == 0:
        continue

    

    for j in i.find_all("td"):
        print(j)
        print("----------------")
        if 'rowspan' in str(j):
            temp_var = j.get_text().strip()
            
            print("potato")
        temp_var = j.get_text().strip()
        #print(temp_var)
        #counter += 1
# Out:
# <td rowspan="2">1
# </td>
# ----------------
# potato
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="900" data-file-width="1500" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/23px-Flag_of_Massachusetts.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/35px-Flag_of_Massachusetts.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Flag_of_Massachusetts.svg/46px-Flag_of_Massachusetts.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Massachusetts" title="Massachusetts">Massachusetts</a>
# </td>
# ----------------
# <td rowspan="2">0.956
# </td>
# ----------------
# potato
# ...

# %%
for i in soup.find_all("tr"):
    counter = 1
    if counter >= 4:
        counter = 1
    if i == 0:
        continue
    for j in i.find_all("td"):
        #print(j)
        if 'rowspan' in str(j):
            temp_var = j.get_text().strip()
            if !isdigit(temp_var):
                state_list.append(temp_var)
            
                
            print(temp_var)
        temp_var = j.get_text().strip()
        print(temp_var)
        counter += 1
# Out:
# potato
# 1
# Massachusetts
# potato
# 0.956
# New Hampshire
# potato
# 3
# Colorado
# potato
# 0.952
# Washington
# 5
# Minnesota
# 0.951
# 6
# Connecticut
# 0.950
# —
# District of Columbia
# potato
# 0.947
# 7
# Hawaii
# 8
# Vermont
# 0.945
# 9
# New Jersey
# 0.943
# 10
# Maryland
# 0.942
# 11
# Virginia
# 0.939
# 12
# Oregon
# 0.938
# 13
# New York
# 0.937
# 14
# Wyoming
# 0.936
# 15
# California
# 0.935
# potato
# 16
# North Dakota
# potato
# 0.934
# Rhode Island
# 18
# Illinois
# 0.932
# potato
# 19
# Alaska
# potato
# 0.931
# Nebraska
# Utah
# potato
# 22
# Maine
# potato
# 0.929
# South Dakota
# Wisconsin
# 25
# Pennsylvania
# 0.928
# —
# United States (average)
# 0.927
# 26
# Florida
# 0.925
# 27
# Montana
# 0.924
# 28
# Iowa
# 0.923
# 29
# Delaware
# 0.922
# 30
# Kansas
# 0.921
# 31
# Idaho
# 0.916
# 32
# Michigan
# 0.913
# 33
# Nevada
# 0.910
# potato
# 34
# North Carolina
# potato
# 0.908
# Ohio
# 36
# Texas
# 0.907
# 37
# Arizona
# 0.906
# 38
# Georgia
# 0.905
# 39
# ...

# %%
nice_function()
# Out:
# <th>Rank
# </th>
# <th>State,<br/>federal district,<br/> or territory
# </th>
# <th>HDI (2022)<br/><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>note 1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th>
# ['Rank', 'State,federal district, or territory', 'HDI (2022)[note 1][1]']
